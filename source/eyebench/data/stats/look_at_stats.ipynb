# %%
import pandas as pd

stats = pd.read_csv('/data/home/shubi/eyebench_private/data/stats/tasks_stats.csv')
stats
# Out:
#                  Unnamed: 0                 OneStop  \
# 0                    BK_col                     NaN
# 1           BK_distribution                     NaN
# 2                BK_overall                     NaN
# 3               BK_per_item                     NaN
# 4        BK_per_participant                     NaN
# ..                      ...                     ...
# 79  n_words_per_participant  5862.2±197 (5595-6175)
# 80              text_domain                    News
# 81            text_language                 English
# 82              text_source       Guardian Articles
# 83                text_type               paragraph
#
#                             CopCo               MECOL2W1  \
# 0                             NaN                    NaN
# 1                             NaN                    NaN
# 2                             NaN                    NaN
# 3                             NaN                    NaN
# ...

# %%
stats.rename(columns={'Unnamed: 0': 'stat'}, inplace=True)

# %%
stats['stat'].unique()
# Out:
# array(['BK_col', 'BK_distribution', 'BK_overall', 'BK_per_item',
#        'BK_per_participant', 'BTD_col', 'BTD_distribution', 'BTD_overall',
#        'BTD_per_item', 'BTD_per_participant', 'CHOSEN_ANSWER_col',
#        'CHOSEN_ANSWER_distribution', 'CHOSEN_ANSWER_overall',
#        'CHOSEN_ANSWER_per_item', 'CHOSEN_ANSWER_per_participant',
#        'CONDITION_col', 'CONDITION_distribution', 'CONDITION_overall',
#        'CONDITION_per_item', 'CONDITION_per_participant',
#        'DIFFICULTY_LEVEL_col', 'DIFFICULTY_LEVEL_distribution',
#        'GENERAL_READING_COMPREHENSION_col',
#        'GENERAL_READING_COMPREHENSION_overall',
#        'GENERAL_READING_COMPREHENSION_per_item',
#        'GENERAL_READING_COMPREHENSION_per_participant', 'HD_col',
#        'HD_distribution', 'HD_overall', 'HD_per_item',
#        'HD_per_participant', 'LEX_col', 'LEX_overall', 'LEX_per_item',
#        'LEX_per_participant', 'QUESTION_LABEL_col',
# ...

# %%
stats[stats['stat'] == 'n_fix']
# Out:
#      stat  OneStop   CopCo MECOL2W1 MECOL2W2 IITBHGC    PoTeC    SBSAT  \
# 69  n_fix  1114034  397883  1208284  1200876  163910  1211325  1315160
#
#      MECOL2
# 69  2409160

# %%
stats[stats['stat'] == 'n_trials']
# Out:
#         stat OneStop CopCo MECOL2W1 MECOL2W2 IITBHGC PoTeC SBSAT MECOL2
# 75  n_trials    9718  4782     4723     4770    2500  2664  1900   9493

# %%
stats[stats['stat'] == 'n_participants']
# Out:
#               stat OneStop CopCo MECOL2W1 MECOL2W2 IITBHGC PoTeC SBSAT MECOL2
# 74  n_participants     180    57      536      562       5    75    95   1098
