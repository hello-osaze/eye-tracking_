# %%
import pandas as pd

df = pd.read_csv(
    '/data/home/shubi/eyebench_private/data/SBSAT/stimuli/combined_stimulus.csv'
)
df
# Out:
#                      filename stimulus_type  sequence_num  word_number   x1  \
# 0     reading-northpole-5.png     northpole             5            1  743
# 1     reading-northpole-5.png     northpole             5            2  778
# 2     reading-northpole-5.png     northpole             5            3  805
# 3     reading-northpole-5.png     northpole             5            4   43
# 4     reading-northpole-5.png     northpole             5            5  101
# ...                       ...           ...           ...          ...  ...
# 3837    reading-flytrap-1.png       flytrap             1          134  566
# 3838    reading-flytrap-1.png       flytrap             1          135  627
# 3839    reading-flytrap-1.png       flytrap             1          136  689
# 3840    reading-flytrap-1.png       flytrap             1          137  732
# 3841    reading-flytrap-1.png       flytrap             1          138  785
#
# ...

# %%
dd = df.groupby(by='filename')['max_word_number'].max().reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dd = df.groupby(by='filename')['max_word_number'].max().reset_index()
#
# File ~/miniforge3/envs/eyebench/lib/python3.12/site-packages/pandas/core/groupby/generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# File ~/miniforge3/envs/eyebench/lib/python3.12/site-packages/pandas/core/base.py:244, in SelectionMixin.__getitem__(self, key)
#     242 else:
#     243     if key not in self.obj:
# ...

# %%
dd.sort_values(by='filename')
# Out:
#                     filename  word_number
# 0     question-dickens-1.png           80
# 1     question-dickens-2.png           49
# 2     question-dickens-3.png           77
# 3     question-dickens-4.png           49
# 4     question-dickens-5.png           51
# 5     question-flytrap-1.png           68
# 6     question-flytrap-2.png           52
# 7     question-flytrap-3.png           94
# 8     question-flytrap-4.png          108
# 9     question-flytrap-5.png           70
# 10     question-genome-1.png           46
# 11     question-genome-2.png           20
# 12     question-genome-3.png           62
# 13     question-genome-4.png           53
# 14     question-genome-5.png           57
# 15  question-northpole-1.png           49
# 16  question-northpole-2.png           97
# 17  question-northpole-3.png           36
# 18  question-northpole-4.png           33
# 19  question-northpole-5.png           69
# 20     reading-dickens-1.png          141
# ...

# %%
a = pd.read_feather(
    path='/data/home/shubi/eyebench_private/data/SBSAT/processed/ia.feather'
)

# %%
a.groupby('unique_trial_id').size().max()
# Out:
# np.int64(740)

# %%
f = pd.read_feather(
    path='/data/home/shubi/eyebench_private/data/SBSAT/processed/fixations.feather'
)

# %%
[print(column) for column in f.columns]
len(f.columns)
# Out:
# original_fixation_index
# participant_id
# TRIAL_INDEX
# CURRENT_FIX_X
# CURRENT_FIX_Y
# CURRENT_FIX_PUPIL
# CURRENT_FIX_DURATION
# CURRENT_FIX_INTEREST_AREA_ID
# CURRENT_FIX_INTEREST_AREA_LABEL
# CURRENT_FIX_INTEREST_AREA_PIXEL_AREA
# CURRENT_FIX_INTEREST_AREA_RUN_ID
# CURRENT_FIX_INTEREST_AREA_DWELL_TIME
# PREVIOUS_SAC_DIRECTION
# PREVIOUS_SAC_ANGLE
# PREVIOUS_SAC_AMPLITUDE
# PREVIOUS_SAC_AVG_VELOCITY
# PREVIOUS_SAC_CONTAINS_BLINK
# PREVIOUS_SAC_BLINK_DURATION
# Session_Name_
# Trial_Index_
# Trial_Recycled_
# total_page
# type
# book_name
# book
# page
# RT
# unique_paragraph_id
# word
# word_index
# start_of_line
# end_of_line
# old_original_word_index
# story_name
# page_number
# CURRENT_FIX_INDEX
# full_paragraph
# full_old_original_word_index
# NEXT_FIX_INTEREST_AREA_INDEX
# PREVIOUS_FIX_INTEREST_AREA_INDEX
# question_index
# unique_trial_id
# INDEX
# AVERAGE_BLINK_DURATION
# AVERAGE_FIXATION_DURATION
# SD_FIXATION_DURATION
# AVERAGE_SACCADE_AMPLITUDE
# SD_SACCADE_AMPLITUDE
# ...

# %%
f[['original_fixation_index', 'book', 'book_name']]
# Out:
#          original_fixation_index  book  book_name
# 0                              0     1    dickens
# 1                              1     1    dickens
# 2                              2     1    dickens
# 3                              3     1    dickens
# 4                              4     1    dickens
# ...                          ...   ...        ...
# 1315155                   460183     4  northpole
# 1315156                   460184     4  northpole
# 1315157                   460185     4  northpole
# 1315158                   460186     4  northpole
# 1315159                   460187     4  northpole
#
# [1315160 rows x 3 columns]

# %%
counts = (
    f.groupby('unique_trial_id').size().reset_index().rename(columns={0: 'n_fixations'})
)
counts
# Out:
#          unique_trial_id  n_fixations
# 0       msd001_dickens_1          510
# 1       msd001_dickens_2          510
# 2       msd001_dickens_3          510
# 3       msd001_dickens_4          510
# 4       msd001_dickens_5          510
# ...                  ...          ...
# 1895  msd107_northpole_1          746
# 1896  msd107_northpole_2          746
# 1897  msd107_northpole_3          746
# 1898  msd107_northpole_4          746
# 1899  msd107_northpole_5          746
#
# [1900 rows x 2 columns]

# %%
f.groupby('unique_trial_id').size().mean()
# Out:
# np.float64(692.1894736842105)

# %%
f.groupby('unique_trial_id').size().max()
# Out:
# np.int64(1188)

# %%
a.question.str.split().apply(len).max()
# Out:
# np.int64(40)
