# %%
from pathlib import Path

import pandas as pd

results_dir = Path.cwd().parent
results_dir
# Out:
# PosixPath('/data/home/shubi/eyebench_private/results')

# %%
data_tasks = [
    'CopCo_TYP',
    'CopCo_RCS',
    'OneStop_TRC_First_NoPreview',
    'OneStop_TRC_First_Preview',
    'OneStop_TRC_Repeated_Preview',
    'OneStop_TRC_Repeated_NoPreview',
    'OneStop_TRC',
    'SBSAT_TRC',
    'SBSAT_STD',
    'PoTeC_TRC',
    'PoTeC_BK',
    'IITBHGC_HD',
    'MECOL2_LEX',
]

# ---------------------------------
# Choose here data_task and run all
# ---------------------------------

data_task = 'OneStop_TRC_First_NoPreview'

################################################
# Load Data

stats = pd.read_csv(
    filepath_or_buffer=results_dir
    / f'eyebenchh_benchmark_results/stats_{data_task}.csv'
)
stats
# Out:
#          metric_type        metric_name eval_type  \
# 0     Discriminative  balanced_accuracy       val
# 1     Discriminative  balanced_accuracy       val
# 2     Discriminative  balanced_accuracy       val
# 3     Discriminative  balanced_accuracy       val
# 4     Discriminative  balanced_accuracy       val
# ...              ...                ...       ...
# 2747  Discriminative              auroc      test
# 2748  Discriminative              auroc      test
# 2749  Discriminative              auroc      test
# 2750  Discriminative              auroc      test
# 2751  Discriminative              auroc      test
#
#                         data_task               model  \
# 0     OneStop_TRC_First_NoPreview              AhnCNN
# 1     OneStop_TRC_First_NoPreview              AhnCNN
# 2     OneStop_TRC_First_NoPreview              AhnCNN
# 3     OneStop_TRC_First_NoPreview              AhnCNN
# 4     OneStop_TRC_First_NoPreview              AhnCNN
# ...

# %% [markdown]
# ## See columns

# %%
stats.iloc[0]
# Out:
# metric_type                             Discriminative
# metric_name                          balanced_accuracy
# eval_type                                          val
# data_task                  OneStop_TRC_First_NoPreview
# model                                           AhnCNN
# eval_regime                   seen_subject_unseen_item
# fold                                                 0
# n_folds                                              1
# fold_list                                          [0]
# n_samples                                          993
# n_unique_y_true                                      2
# n_unique_y_pred                                      2
# y_true_single                                    False
# y_pred_single                                    False
# y_true_distribution                   {1: 861, 0: 132}
# y_pred_distribution                   {1: 775, 0: 218}
# extra_classes_in_y_pred                            NaN
# ...

# %% [markdown]
# ## Check Nans

# %%
import numpy as np

stats[np.isnan(stats['score'])][
    [
        'eval_type',
        'eval_regime',
        'data_task',
        'metric_type',
        'metric_name',
        'fold',
        'fold_list',
        'n_samples',
        'y_true_single',
        'y_pred_single',
        'y_true_distribution',
        'score',
    ]
].drop_duplicates()
# Out:
# Empty DataFrame
# Columns: [eval_type, eval_regime, data_task, metric_type, metric_name, fold, fold_list, n_samples, y_true_single, y_pred_single, y_true_distribution, score]
# Index: []

# %% [markdown]
# ## Check Nulls

# %%
stats[stats['score'].isna()][
    [
        'model',
        'eval_type',
        'eval_regime',
        'data_task',
        'metric_type',
        'metric_name',
        'fold',
        'fold_list',
        'n_samples',
        'y_true_single',
        'y_pred_single',
        'y_true_distribution',
        'score',
    ]
].drop_duplicates()
# Out:
# Empty DataFrame
# Columns: [model, eval_type, eval_regime, data_task, metric_type, metric_name, fold, fold_list, n_samples, y_true_single, y_pred_single, y_true_distribution, score]
# Index: []

# %%
stats[stats['score'].isna()][
    [
        'data_task',
        'metric_type',
        'metric_name',
        'fold',
        'y_true_single',
        'y_pred_single',
        'y_true_distribution',
        'y_pred_distribution',
        'extra_classes_in_y_pred',
        'score',
    ]
].drop_duplicates()
# Out:
# Empty DataFrame
# Columns: [data_task, metric_type, metric_name, fold, y_true_single, y_pred_single, y_true_distribution, y_pred_distribution, extra_classes_in_y_pred, score]
# Index: []

# %% [markdown]
# # N samples Validation

# %%
import pandas as pd


def highlight_nsample_differences(
    stats: pd.DataFrame, meta_cols=None, minimal: bool = False
):
    # Create eval_type_regime column (for compact grouping)
    stats = stats.copy()
    stats['eval_type_regime'] = stats['eval_type'] + '_' + stats['eval_regime']

    # Pivot to see n_samples per model
    stats_pivot = stats.pivot_table(
        index=['data_task', 'metric_name', 'fold', 'eval_type_regime'],
        columns='model',
        values='n_samples',
        aggfunc='first',
    ).sort_values(by=['metric_name', 'fold'])

    # Reset index to make metadata accessible as columns
    stats_pivot = stats_pivot.reset_index()

    if meta_cols is None:
        meta_cols = ['data_task', 'metric_name', 'fold', 'eval_type_regime']

    model_cols = [c for c in stats_pivot.columns if c not in meta_cols]
    stats_pivot = stats_pivot.copy()

    # Compute majority value (mode) per row
    stats_pivot['majority_val'] = stats_pivot[model_cols].mode(axis=1)[0]

    # Identify differing cells
    diff_mask = stats_pivot[model_cols].ne(stats_pivot['majority_val'], axis=0)
    stats_pivot['n_unique_n_samples'] = stats_pivot[model_cols].nunique(axis=1)

    if minimal:
        # Keep only rows with differences
        rows_with_diff = diff_mask.any(axis=1)
        df_min = stats_pivot.loc[rows_with_diff, :]
        # Keep only model columns that ever differ
        cols_with_diff = diff_mask.any(axis=0)
        cols_to_keep = (
            meta_cols + list(cols_with_diff[cols_with_diff].index) + ['majority_val']
        )
        df_to_show = df_min[cols_to_keep]
    else:
        df_to_show = stats_pivot

    # print models and eval_type_regime combinations that differ
    differing_rows = stats_pivot[stats_pivot['n_unique_n_samples'] > 1]
    print('Rows with differing n_samples between models:')
    for _, row in differing_rows.sort_values(
        by=['metric_name', 'eval_type_regime', 'fold']
    ).iterrows():
        differing_models = [
            col for col in model_cols if row[col] != row['majority_val']
        ]
        print(
            f'{row["data_task"]} \t {row["metric_name"]} \t Fold: {row["fold"]} \t {row["eval_type_regime"]} \t  {differing_models}'
        )

    # Styling function for highlighting
    def highlight_row(row):
        mode_val = row['majority_val']
        return [
            'color: red; font-weight: bold'
            if (col in model_cols and row[col] != mode_val)
            else ''
            for col in df_to_show.columns
        ]

    styled = df_to_show.style.apply(highlight_row, axis=1).format(precision=0)
    return styled

# %%
# Show only rows and model columns that contain red values
for data_task in data_tasks:
    print(f'Data Task: {data_task}')
    stats = pd.read_csv(
        filepath_or_buffer=results_dir
        / f'eyebench_benchmark_results/stats_{data_task}.csv'
    )
    minimal_df = highlight_nsample_differences(stats, minimal=True)
    display(minimal_df)
# Out:
# Data Task: CopCo_TYP
# Rows with differing n_samples between models:
# <style type="text/css">
# </style>
# <table id="T_ee085">
#   <thead>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th id="T_ee085_level0_col0" class="col_heading level0 col0" >data_task</th>
#       <th id="T_ee085_level0_col1" class="col_heading level0 col1" >metric_name</th>
#       <th id="T_ee085_level0_col2" class="col_heading level0 col2" >fold</th>
#       <th id="T_ee085_level0_col3" class="col_heading level0 col3" >eval_type_regime</th>
#       <th id="T_ee085_level0_col4" class="col_heading level0 col4" >majority_val</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# Data Task: CopCo_RCS
# Rows with differing n_samples between models:
# <style type="text/css">
# </style>
# <table id="T_383be">
#   <thead>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th id="T_383be_level0_col0" class="col_heading level0 col0" >data_task</th>
# ...

# %%
# for task in data_tasks:
#     print(f'Checking {task}...')
#     result = subprocess.run(
#         ['python', str(results_dir / 'validation/check_task_outputs.py'), task],
#         capture_output=True,
#         text=True,
#     )
#     print(result.stdout)
#     if result.stderr:
#         print(f'Errors: {result.stderr}')
#     print('-' * 80)

zz = []
for data_task in data_tasks:
    stats = pd.read_csv(
        filepath_or_buffer=results_dir
        / f'eyebench_benchmark_results/stats_{data_task}.csv'
    )

    z = (
        stats.drop_duplicates(subset=['model', 'fold', 'eval_type', 'eval_regime'])
        .value_counts(['data_task', 'model', 'fold', 'eval_type'])
        .reset_index()
    )
    # print(data_task)
    zz.append(z[(z['count'] < 4) & (z['fold'] != 'all')])

zz_df = pd.concat(zz)
zz_df
# Out:
#                           data_task                       model fold  \
# 288    OneStop_TRC_Repeated_Preview                      AhnCNN    5
# 289    OneStop_TRC_Repeated_Preview                      AhnCNN    6
# 292    OneStop_TRC_Repeated_Preview  SupportVectorMachineMLArgs    6
# 295    OneStop_TRC_Repeated_Preview               XGBoostMLArgs    5
# 296    OneStop_TRC_Repeated_Preview               XGBoostMLArgs    6
# ..                              ...                         ...  ...
# 343  OneStop_TRC_Repeated_NoPreview                      AhnRNN    8
# 346  OneStop_TRC_Repeated_NoPreview                BEyeLSTMArgs    7
# 347  OneStop_TRC_Repeated_NoPreview                BEyeLSTMArgs    8
# 348  OneStop_TRC_Repeated_NoPreview               RoberteyeWord    7
# 349  OneStop_TRC_Repeated_NoPreview               RoberteyeWord    8
#
#     eval_type  count
# 288      test      3
# 289       val      3
# 292       val      3
# 295      test      3
# 296       val      3
# ...
