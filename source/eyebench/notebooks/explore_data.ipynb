# %%
from src.configs.constants import DataSets
from src.configs.data import get_data_args
from src.data.utils import load_raw_data

# %%
datasets = {}
for dataset_name in [DataSets.COPCO]:
    datasets[dataset_name] = {
        'raw_ia': load_raw_data('..' / get_data_args(dataset_name).raw_ia_path),
        'raw_fixations': load_raw_data(
            '..' / get_data_args(dataset_name).raw_fixations_path
        ),
        'ia': load_raw_data('..' / get_data_args(dataset_name).ia_path),
        'fixations': load_raw_data('..' / get_data_args(dataset_name).fixations_path),
    }

# %%
datasets['CopCo']['ia']
